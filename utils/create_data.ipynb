""".split('$')

results = []
for item in tqdm(items):
    if len(item) > 1:
        finded = searcher.search(item)
        for finded_item in finded:
            # Создаем строку в формате item|finded_item[0]|finded_item[1]|...
            row = [item] + list(finded_item)
            results.append(row)

# Создаем DataFrame
columns = ['item'] + [f'found_{i}' for i in range(len(finded_item))]
df = pd.DataFrame(results, columns=columns)
# Out:
# 100%|██████████| 202/202 [02:48<00:00,  1.20it/s]

# %%
df
# Out:
#                                                   item  \
# 0                             Toyota RAV4 XLE AWD 2025
# 1                             Toyota RAV4 XLE AWD 2025
# 2                             Toyota RAV4 XLE AWD 2025
# 3                             Toyota RAV4 XLE AWD 2025
# 4                             Toyota RAV4 XLE AWD 2025
# ...                                                ...
# 1207                        Isuzu NPR-HD Crew Cab 2025
# 1208  Freightliner Sprinter 2500 Worker Cargo Van 2025
# 1209  Freightliner Sprinter 2500 Worker Cargo Van 2025
# 1210                  Iveco Daily 35S14 Cargo Van 2025
# 1211            Volkswagen Caddy Maxi Cargo Van 2025\n
#
#                                                 found_0 found_1
# 0     Overlays NEW 2019-2025 Toyota Rav4 XLE AWD Hyb...   39.85
# 1     Overlays NEW 2019-2025 Toyota Rav4 XLE AWD Glo...   38.95
# 2     Overlays NEW 2019-2025 Toyota Rav4 XLE AWD Hyb...   39.85
# ...

# %%
df.drop('found_1', axis=1, inplace=True)

# %%
df.rename(columns={'item': 'query', 'found_0': 'word'}, inplace=True)

# %%
df.head(20)
# Out:
#                        query  \
# 0   Toyota RAV4 XLE AWD 2025
# 1   Toyota RAV4 XLE AWD 2025
# 2   Toyota RAV4 XLE AWD 2025
# 3   Toyota RAV4 XLE AWD 2025
# 4   Toyota RAV4 XLE AWD 2025
# 5   Toyota RAV4 XLE AWD 2025
# 6   Toyota RAV4 XLE AWD 2025
# 7   Toyota RAV4 XLE AWD 2025
# 8   Toyota RAV4 XLE AWD 2025
# 9   Toyota RAV4 XLE AWD 2025
# 10     BMW X3 xDrive30i 2025
# 11     BMW X3 xDrive30i 2025
# 12     BMW X3 xDrive30i 2025
# 13     BMW X3 xDrive30i 2025
# 14     BMW X3 xDrive30i 2025
# 15     BMW X3 xDrive30i 2025
# 16     BMW X3 xDrive30i 2025
# 17     BMW X3 xDrive30i 2025
# 18     BMW X3 xDrive30i 2025
# 19     BMW X3 xDrive30i 2025
#
#                                                  word
# 0   Overlays NEW 2019-2025 Toyota Rav4 XLE AWD Hyb...
# 1   Overlays NEW 2019-2025 Toyota Rav4 XLE AWD Glo...
# 2   Overlays NEW 2019-2025 Toyota Rav4 XLE AWD Hyb...
# 3   Overlays NEW 2019-2025 Toyota Rav4 XLE AWD Mat...
# 4   2022 - 2025 Toyota Rav4 XLE AWD Hybrid LED 5-p...
# ...

# %%
df.to_csv('from_ebay_2.csv')

# %%
df.values
# Out:
# array([['Toyota RAV4 XLE AWD 2025',
#         'Overlays NEW 2019-2025 Toyota Rav4 XLE AWD Hybrid Matte Blackout Emblems Kits'],
#        ['Toyota RAV4 XLE AWD 2025',
#         'Overlays NEW 2019-2025 Toyota Rav4 XLE AWD Gloss Blackout Emblems Kits'],
#        ['Toyota RAV4 XLE AWD 2025',
#         'Overlays NEW 2019-2025 Toyota Rav4 XLE AWD Hybrid Gloss Blackout Emblems Kits'],
#        ...,
#        ['Freightliner Sprinter 2500 Worker Cargo Van 2025',
#         ' Mercedes-Benz Sprinter Van NCV3 & VS30 (Van Year 2007-Current) Cool Gray'],
#        ['Iveco Daily 35S14 Cargo Van 2025',
#         'Iveco Daily Box Alborn (Intermodellbau 2013)'],
#        ['Volkswagen Caddy Maxi Cargo Van 2025\n',
#         'Rubber License Plate Holder Mounting Adapter Bumper Bracket Frame for Volkswagen']],
#       dtype=object)

# %%
for pair in df.values:
    if '<sep>' in pair[0] or '<sep>' in pair[1]:
        print(pair[0], pair[1])

# %%
res_df = pd.DataFrame({'query': [], 'word': [], 'label': []})

# %%
data = open('custom_labels.txt').read()
# print(data)
for row in data.split('<|>'):
    splitted_row = row.split('<sep>')
    if len(splitted_row) > 1:
        res_df.loc[len(res_df)] = {
            'query': splitted_row[0],
            'word': splitted_row[1],
            'label': splitted_row[2],
        }

# %%
res_df
# Out:
#                                query  \
# 0      Apple iPhone 16 Pro Max 256GB
# 1      Apple iPhone 16 Pro Max 256GB
# 2      Apple iPhone 16 Pro Max 256GB
# 3      Apple iPhone 16 Pro Max 256GB
# 4      Apple iPhone 16 Pro Max 256GB
# ...                              ...
# 4022  GMC Terrain Elevation AWD 2025
# 4023  GMC Terrain Elevation AWD 2025
# 4024  GMC Terrain Elevation AWD 2025
# 4025  GMC Terrain Elevation AWD 2025
# 4026  GMC Terrain Elevation AWD 2025
#
#                                                    word label
# 0     APPLE IPHONE 16 PRO MAX 256GB 512GB (FACTORY U...     1
# 1     Apple iPhone 16 Pro Max 256GB 512GB 1TB Unlock...     1
# 2     Apple iPhone 16 Pro Max 256GB Unlocked Excelle...     1
# 3     Apple iPhone 14 Pro Max 256GB Network Unlocked...     0
# 4     Apple iPhone 14 Pro Max 256GB Unlocked Very Go...     0
# ...                                                 ...   ...
# 4022  19132944 AC Delco Transfer Case Output Shaft S...     0
# ...

# %%
res_df.iloc[2487]['query'], res_df.iloc[2487]['word']
# Out:
# ('Huawei MateBook X Pro Intel i7-1260P 16GB RAM 1TB SSD',
#  'HUAWEI MateBook X Pro 2024 Laptop Core Ultra 9 /7 14.2 inch 980g Touch Screen')

# %%
res_df.iloc[1000:1050]
# Out:
#                                          query  \
# 1000    ASUS ROG Zephyrus G14 32GB RAM 1TB SSD
# 1001    ASUS ROG Zephyrus G14 32GB RAM 1TB SSD
# 1002    ASUS ROG Zephyrus G14 32GB RAM 1TB SSD
# 1003    ASUS ROG Zephyrus G14 32GB RAM 1TB SSD
# 1004    ASUS ROG Zephyrus G14 32GB RAM 1TB SSD
# 1005    ASUS ROG Zephyrus G14 32GB RAM 1TB SSD
# 1006   ASUS Zenbook 14 OLED 16GB RAM 512GB SSD
# 1007   ASUS Zenbook 14 OLED 16GB RAM 512GB SSD
# 1008   ASUS Zenbook 14 OLED 16GB RAM 512GB SSD
# 1009   ASUS Zenbook 14 OLED 16GB RAM 512GB SSD
# 1010   ASUS Zenbook 14 OLED 16GB RAM 512GB SSD
# 1011   ASUS Zenbook 14 OLED 16GB RAM 512GB SSD
# 1012   ASUS Zenbook 14 OLED 16GB RAM 512GB SSD
# 1013   ASUS Zenbook 14 OLED 16GB RAM 512GB SSD
# 1014   ASUS Zenbook 14 OLED 16GB RAM 512GB SSD
# 1015   ASUS Zenbook 14 OLED 16GB RAM 512GB SSD
# 1016        ASUS ROG Flow Z13 16GB RAM 1TB SSD
# 1017        ASUS ROG Flow Z13 16GB RAM 1TB SSD
# 1018        ASUS ROG Flow Z13 16GB RAM 1TB SSD
# ...

# %%
res_df.to_csv('from_ebay_labeled.csv')
